# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2cd6f77f-8b1a-41a7-bc58-f70cab7348e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2cd6f77f-8b1a-41a7-bc58-f70cab7348e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip shapes.v3i.yolov8.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/frame_000010_original_jpg.rf.b5c388210524550c9ea81855ce47a428.txt
#   inflating: train/labels/frame_000010_original_jpg.rf.c690d4319a60d7ecd11d91c92f491511.txt
#   inflating: train/labels/frame_000010_original_jpg.rf.cb258542e3986ae30f545cd1639cde40.txt
#   inflating: train/labels/frame_000010_original_jpg.rf.dfdaf7cc3beb28ca09648e789365c2d3.txt
#   inflating: train/labels/frame_000010_original_jpg.rf.ef78d8299ac55de02d0c937c0dcd3cf7.txt
#   inflating: train/labels/frame_000010_rot_180_jpg.rf.032911d83d79f846e67c670cb90be9a2.txt
#   inflating: train/labels/frame_000010_rot_180_jpg.rf.03724a5f6a039ffd1e05ee9c0edd09a8.txt
#   inflating: train/labels/frame_000010_rot_180_jpg.rf.069548f72fe85f781d105667bc615504.txt
#   inflating: train/labels/frame_000010_rot_180_jpg.rf.2862332f7b7ab00b5241b670b3766613.txt
#   inflating: train/labels/frame_000010_rot_180_jpg.rf.2de3160559144e317c58a790500c67b9.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.8 MB/s eta 0:00:00
# ...

# %%
# !yolo version
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 8.4.13

# %%
# !ls
# !ls train
# !cat data.yaml
# Out:
# data.yaml	    README.roboflow.txt  sample_data		train
# README.dataset.txt  runs		 shapes.v3i.yolov8.zip	yolov8s.pt
# images	labels
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 13
# names: ['bcircle', 'bcube', 'btriangle', 'mtcircle', 'mtcube', 'mttriangle', 'rcircle', 'rcube', 'rtriangle', 'wb', 'ycircle', 'ycube', 'ytriangle']
#
# roboflow:
#   workspace: robotics-project-vsdgg
#   project: shapes-oauf5
#   version: 3
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/robotics-project-vsdgg/shapes-oauf5/dataset/3

# %%
# %%writefile data.yaml
#
# train: ../train/images
# val: ../train/images
# test: ../train/images
#
# nc: 13
# names: ['bcircle', 'bcube', 'btriangle', 'mtcircle', 'mtcube', 'mttriangle', 'rcircle', 'rcube', 'rtriangle', 'wb', 'ycircle', 'ycube', 'ytriangle']
#
# roboflow:
#   workspace: robotics-project-vsdgg
#   project: shapes-oauf5
#   version: 3
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/robotics-project-vsdgg/shapes-oauf5/dataset/3
# Out:
# Overwriting data.yaml

# %%
# !yolo detect train \
  model=yolov8s.pt \
  data=data.yaml \
  imgsz=640 \
  epochs=80 \
  batch=16 \
  lr0=0.003 \
  cos_lr=True \
  hsv_h=0.015 \
  hsv_s=0.6 \
  hsv_v=0.4 \
  degrees=8 \
  translate=0.1 \
  scale=0.4 \
  mosaic=0.3 \
  close_mosaic=10
# Out:
# Ultralytics 8.4.13 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
